# %%
import pandas as pd

file_path = '../data/cola_public/raw/in_domain_train.tsv'
data = pd.read_csv(file_path, sep='\t')

data.head(50)
# Out:
#     gj04  1 Unnamed: 2  \
# 0   gj04  1        NaN
# 1   gj04  1        NaN
# 2   gj04  1        NaN
# 3   gj04  1        NaN
# 4   gj04  1        NaN
# 5   gj04  1        NaN
# 6   gj04  1        NaN
# 7   gj04  1        NaN
# 8   gj04  1        NaN
# 9   gj04  1        NaN
# 10  gj04  1        NaN
# 11  gj04  1        NaN
# 12  gj04  1        NaN
# 13  gj04  1        NaN
# 14  gj04  1        NaN
# 15  gj04  1        NaN
# 16  gj04  1        NaN
# 17  gj04  0          *
# 18  gj04  1        NaN
# 19  gj04  0          *
# 20  gj04  1        NaN
# 21  gj04  0          *
# 22  gj04  0          *
# 23  gj04  1        NaN
# 24  gj04  0          *
# 25  gj04  0          *
# 26  gj04  1        NaN
# 27  gj04  1        NaN
# 28  gj04  1        NaN
# 29  gj04  1        NaN
# 30  gj04  1        NaN
# 31  gj04  1        NaN
# 32  gj04  1        NaN
# 33  gj04  1        NaN
# 34  gj04  1        NaN
# 35  gj04  1        NaN
# 36  gj04  1        NaN
# 37  gj04  1        NaN
# ...
